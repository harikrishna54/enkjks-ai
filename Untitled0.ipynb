# %% [markdown]
# <a href="https://colab.research.google.com/github/harikrishna54/enkjks-ai/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers

# %%
from transformers import pipeline
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work

# %%
generator =pipeline('text-generation',model="gpt2")
# Out:
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# Device set to use cpu

# %%
prompt ="once upon a time, a little boy"
output =generator(prompt, max_length=50)

print(output[0]["generated_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ...

# %%
prompt = "explain ai: biriyani"
output = generator (prompt,max_length=80)
print(output[0]["generated_text"])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=80) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# explain ai: biriyani (he does not understand) and shahadhi (he believes in). Ai: shahadhi is a form of shahadhi.
#
# biriyani: biriyani is the name of ai. He does not understand. [2]
#
# he does not understand. [2] p. 11: This is why he says, "He does not understand." He does not understand. [2]
#
# He understands. [2] p. 13: "He does not understand." He does not understand. [2]
#
# (He does not understand) and (He believes in). p. 25: It is a form of shahadhi.
#
# (He does not understand) and (He believes in). p. 27: (He does not understand). [2]
#
# He does not understand) and (He believes in). p. 38: "He does not understand." He does not understand. [2]
#
# ...
